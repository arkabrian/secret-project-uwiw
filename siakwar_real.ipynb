# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
import time

url = "https://academic.ui.ac.id/"
# path = r"C:\Users\Arka Brian\Documents\Arka\Project kodingan\BOT SIAKWAR\msedgedriver.exe"

browser_driver = webdriver.Edge()
browser_driver.get(url)

# %%
username_field = browser_driver.find_element("name", "u")
username_field.send_keys("arka.brian")
password_field = browser_driver.find_element("name", "p")
password_field.send_keys("saitamu1304++")
password_field.send_keys(Keys.RETURN)

mouse = ActionChains(browser_driver)

isi_irs = browser_driver.find_element("link text", "IRS")
mouse.move_to_element(isi_irs).perform()

isi_ubah_irs = browser_driver.find_element("link text", "Isi/Ubah IRS")

mouse.move_to_element(isi_ubah_irs).click().perform()

list_matkul = [
    "716709-2", #Arsitektur Komputer Modern 01
    "716721-3", #Jaringan Telekomunikasi 02
    "716725-3", #Keamanan Jaringan Komputer 02
    "716736-2", #Probabilitas dan Prosess Stokastik 02
    "716740-3", #Rekayasa Perangkat Lunak 02
    "716742-3", #Sistem Waktu Nyata dan IoT 01
    "716752-2"  #Teori Sinyal dan Sistem 02
    ]

for id_matkul in list_matkul:
    radio_inputs = browser_driver.find_element(By.CSS_SELECTOR, f"input[value='{id_matkul}']")
    radio_inputs.click()
    

time.sleep(0.5)

submit = browser_driver.find_element_by_name("submit")
submit.click()

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

def find_element_with_retry(driver, by, value, max_attempts=10, retry_interval=3):
    attempts = 0
    while attempts < max_attempts:
        try:
            element = driver.find_element(by, value)
            return element
        except:
            attempts += 1
            time.sleep(retry_interval)
            driver.refresh()
    raise Exception(f"Element not found after {max_attempts} attempts")

def main():
    url = "https://academic.ui.ac.id/"
    path = r"C:\Users\Arka Brian\Documents\Arka\Project kodingan\BOT SIAKWAR\msedgedriver.exe"

    browser_driver = webdriver.Edge(executable_path=path)

    # Set a maximum time limit for all operations (30 minutes)
    max_total_time = 30 * 60
    total_time = 0

    while total_time < max_total_time:
        try:
            browser_driver.get(url)

            # Find the username field with retry
            username_field = find_element_with_retry(browser_driver, "name", "u")
            username_field.send_keys("arka.brian")

            # Find the password field with retry
            password_field = find_element_with_retry(browser_driver, "name", "p")
            password_field.send_keys("saitamu1304++")
            password_field.send_keys(Keys.RETURN)

            mouse = ActionChains(browser_driver)

            # Find the "IRS" link with retry
            isi_irs = find_element_with_retry(browser_driver, "link text", "IRS")
            mouse.move_to_element(isi_irs).perform()

            isi_ubah_irs = browser_driver.find_element("link text", "Isi/Ubah IRS")
            mouse.move_to_element(isi_ubah_irs).click().perform()

            # If all operations are successful, break the loop
            break

        except Exception as e:
            print(f"An error occurred: {str(e)}")
            # Wait before retrying
            time.sleep(5)
            total_time += 5

    # Close the browser window
    

if __name__ == "__main__":
    main()

# %% [markdown]
# <h1>JOKIAN</h1>

# %%
username = 'ahmad.nauval'
password = 'sukseswar12345'

list_matkul = [
  '717253-2',
  '717261-3',
  '717264-2',
  '717431-3',
  '717274-3',
  '717276-3',
  '717278-3',
  '717284-3',
  '716186-2'
]

# %%
username = 'naila.karima12'
password = 'naila12'

list_matkul = [
  '717252-2',
  '717261-3',
  '717264-2',
  '724286-3',
  '717274-3',
  '717276-3',
  '717278-3',
  '717284-3',
  '716182-2'
]

# %%
username = 'muhammad.hanif214'
password = 'hnipp21'

list_matkul = [
  '717237-2',
  '717247-2',
  '717249-2',
  '717270-3',
  '717281-3',
  '717262-3',
  '716638-3',
  '717272-3'
]

# %%
username = 'mochamad.luthf'
password = 'khainama22'

list_matkul = [
  '716623-3',
  '716629-3',
  '716635-4',
  '716650-2',
  '716651-2',
  '716666-4',
  '716693-2'
]

# %%
username = 'fathia.zulfa'
password = 'ISNTITisntit13'

list_matkul = [
  '716711-2',
  '716719-3',
  '716727-3',
  '716733-3',
  '716738-2',
  '716745-3',
  '716747-3'
]

# %%
username = 'fadli.nur11'
password = '2002fadli'

list_matkul = [
  '720547-3',
  '720389-2',
  '720437-3',
  '720501-2',
  '720385-2',
  '720457-2',
  '720518-2',
  '720376-2',
  '720505-3',
  '720400-2'
]
